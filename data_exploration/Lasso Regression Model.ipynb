# %% [markdown]
# ## Lasso Regression Modelling
#
# #### Using lasso regression, let's predict a citizen's perception of Chinese Influence
#
# Lasso regression provides the opportunity to compare models to determine if regression (treating response variables as continuous even though they are ordinal) would fit the data best.
#
# The following modeling allows for manipulation of class labels, categorical or binary responses, and feature selection. This is an experimental model and should not be counted as fully deterministic.

# %%
import numpy as np
# set a seed for reproducibility
np.random.seed(23)

import pandas as pd
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer

# to scale our data
from sklearn.preprocessing import MinMaxScaler

# to generate k-folds from the data
from sklearn.model_selection import KFold, train_test_split

# use sklearn.metrics to calculate a confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# to calulate distance matrix
from sklearn.metrics import pairwise_distances

# to use in building graphs for DT
import graphviz 

# to use in viewing feature importance from random forest 
import seaborn as sns

# to export dataframes
import dataframe_image as dfi

# to build out Lasso regression 
from sklearn.linear_model import LassoCV

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: scikit-learn in /Users/natalie_kraft/anaconda3/lib/python3.8/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/natalie_kraft/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.21.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/natalie_kraft/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /Users/natalie_kraft/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied: scipy>=0.19.1 in /Users/natalie_kraft/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.7.1)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=90ac19b34e26070fa6f8c82c861a6b6c734c57eec1f206ac7c7271230b2c64ea
#   Stored in directory: /Users/natalie_kraft/Library/Caches/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# import data
model = pd.read_csv(r'/Users/natalie_kraft/Documents/LAS/NIGr6_trans_dt_reduced.csv')

# %%
model = model.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ## The following functions are defined as...
#
# > discretize (mapping, labelName, df): turns the categorical/ordinal response into binary or other discretized value
#
# > dtree(x_train, y_train, x_test, criterion, random_state, depth, prob): creates a decision tree using the training data set and then predicts the labels for the test dataset
# - users can specify tree depth as well as use of gini/entropy
# - return the tree and the prediction accuracy
#
# > randomforest(x_train, y_train, x_test, criterion, random_state, depth, prob): builds 100 decision trees to determine relevance of attributes based on different split
# - returns all of the trees and the prediction accuracies
#
# > featureImportance(x_train, y_train, x_test, criterion, random_state, depth, prob, runningModel, threshold): builds a random forest, calculates feature importance based off the forest, determines relevant attributes to model, builds reduced attribute model
# - returns model with reduced attributes based upon threshold set
#
# > evaluation_measures(y_true, y_pred): determining accuracy and confusion matrix

# %%
def discretize( mapping, labelName, df ):

    # what if class labels are binary 

    if mapping != None:
        df[labelName] = df[labelName].map(mapping)
    
    # drop tribe_names first as it has string data (can't be imputed)
    if labelName == "tribe_name":
        labels = df['tribe_name']
    
    df = df.drop(["tribe_name"], axis=1)
        
    # drop columns with only missing values
    todrop = []
    # summarize the number of rows with missing values for each column
    for i in range(df.shape[1]):
        # count number of rows with missing values
        n_miss = df[df.columns[i]].isna().sum()
        if n_miss == 2400: 
            # print("WARNING: /n/n")
            todrop.append(df.columns[i])
        perc = n_miss / df.shape[0] * 100
        # print('> %d, Missing: %d (%.1f%%)' % (i, n_miss, perc))

    df = df.drop(columns=todrop)
    
    # fill in missing values 
    imputer = KNNImputer(n_neighbors=3, weights="uniform")
    t = imputer.fit_transform(df)

    df = pd.DataFrame(t, columns=df.columns)
    
    # round all labels to a whole number 
    if not labelName == "tribe_name":
        labels = df[labelName]
  
    
    # remove unneeded labels 
    vars = ['econInfluence', 'posnegInfluence', 'posImageChina', 'negImageChina', 
            'econAssistance', 'region']
    df = df.drop(vars, axis=1)
 
    return df, labels

# %%
def evaluation_measures(y_true, y_pred):

    # binary equivalent for accuracy
    # cm = confusion_matrix(true_labels, pred_labels)
    # accuracy = (cm[0][0] + cm[1][1]) / (cm[0][0] + cm[1][1] + cm[0][1] + cm[1][0])
    
    cm = confusion_matrix(y_true, y_pred)
    # tp + tn / tp + tn + fp + fn
    # generic values used in anticipation of test cases having more than two class labels
    accuracy = sum(cm[i][i] for i in range(cm.shape[0])) / cm.sum()
    
    # return as a list
    return [accuracy, cm]

# %%
def feature_importance(reg, accuracy, modelColumns):
    
    features = []
    removedFeatures = []
    # Which attributes are most predictive of the outcome variable?
    for i in range(0, len(reg.coef_)):
        if reg.coef_[i] != 0:
            features.append([modelColumns[i], reg.coef_[i]])
        else:
            removedFeatures.append(modelColumns[i])
            
   
    print(f'Model coefficients:\n{features}')
    
    print()
    print(f'Model features removed include:\n {removedFeatures}')

    print()
    # Note we called this 'lamda' in class, but sklearn calls it alpha (should be ~3.196)
    print(f'The shinkage coefficient hyperparameter chosen by CV: {reg.alpha_}')

# %%
def regression_lasso(X_train, X_test, y_train, y_test, i, random_state, printC, modelColumns):
    
    reg = LassoCV(cv=i, random_state=random_state).fit(X_train, y_train)
    pred = reg.predict(X_test)
    
    pred = np.around(pred)
    accuracy, cm = evaluation_measures(y_test, pred)
    
    if printC is True:
        feature_importance(reg, accuracy, modelColumns)
        
    return [accuracy, cm, pred]

# %%
def regression_lasso_cross(label, X_train, X_test, y_train, y_test, random_state):
    
    scatter = []
    highestVal = 0
    bestCross = -1
    
    for i in range(2, 20):
        
        evaluations = regression_lasso(X_train, X_test, y_train, y_test, i, random_state, False, None)
        
        scatter.append([label, i, evaluations[0]])
        if evaluations[0] > highestVal: 
            highestVal = evaluations[0]
            bestCross = i
        
    return scatter, highestVal, bestCross

# %% [markdown]
# ## Predict your model
#
# #### What do you want to predict? Choose your variable first:
# - q81a - econInfluence   - China's economic quantity of influence
# - q81b - posnegInfluence - China's positive or negative influence
# - q81c - posImageChina   - Positive quality of Chinese influence
# - q81d - negImageChina   - Negative quality of Chinese influence
# - q81e - econAssistance  - China's economic assistance meets country needs

# %%
# choose your variable here 
predictor = "econAssistance"

# testing dataset size
size = 0.25

# %%
# listing of all of the mappings to remove invalid outputs 

# econInfluence
key_q81a_all =  {
    9:-1, # don't know
    0:1, # None
    1:2, # A little 
    2:3, # some
    3:4, # alot 
}

key_q81a =  {
    0:0, # None
    1:1, # A little 
    2:1, # some
    3:1, # alot 
}

# posnegInfluence
key_q81b_all =  {
    1:1, # very negative
    2:2, # somewhat negative
    3:3, # neutral 
    4:4, # somewhat positive
    5:5, # very positive
    9:3, # neutral 
}

key_q81b =  {
    1:1, # very negative
    2:1, # somewhat negative
    3:2, # neutral 
    4:3, # somewhat positive
    5:3, # very positive
    9:2, # neutral 
}

# posImageChina
key_q81c_all = {
    1:1, # support for international affairs 
    2:2, # non interference in African affairs 
    3:3, # investment in infrastructure 
    4:4, # business investment 
    5:5, # cost of Chinese goods 
    6:6  # soft power
}

key_q81c = {
    1:1, # support for international affairs 
    2:2, # non interference in African affairs 
    3:3, # investment in infrastructure 
    4:3, # business investment 
    5:4, # cost of Chinese goods 
    6:5  # soft power
}

# negImageChina
key_q81d_all = {
    1:1, # extracting resources
    2:2, # land grabbing
    3:3, # corruption
    4:4, # taking jobs from locals 
    5:5, # quality of Chinese goods 
    6:6  # soft power
}

key_q81d = {
    1:1, # extracting resources
    2:1, # land grabbing
    3:2, # corruption
    4:3, # taking jobs from locals 
    5:3, # quality of Chinese goods 
    6:4  # soft power
}

# econAssistance
key_q81e_all =  {
    1:1, # very bad
    2:2, # somewhat bad
    3:3, # neutral 
    4:4, # somewhat good
    5:5, # very good
    9:3, # dont know
}

key_q81e =  {
    1:1, # very bad
    2:1, # somewhat bad
    3:2, # neutral 
    4:3, # somewhat good
    5:3, # very good
    9:2, # dont know
}

allKeys = [key_q81a_all, key_q81a, key_q81b_all, key_q81b, key_q81c_all, key_q81c, 
           key_q81d_all, key_q81d, key_q81e_all, key_q81e]

allVars = ['econInfluence', 'econInfluence', 'posnegInfluence', 'posnegInfluence',
           'posImageChina', 'posImageChina', 'negImageChina', 'negImageChina', 'econAssistance', 'econAssistance']

# %% [markdown]
# ### Run model with each response variable
#
# Determine accuracy for each response variable based off a determination on model's best cross validation splits
#
# __Average results for full and reduced responses__
# In order to show the benefits of reducing the categorical/ordinal responses of response variables into larger
# groups, the average for all predictors is laid out.

# %%
modelStatus = []

for idx, key in enumerate(allKeys): 
    
    print("\nLet's work on " + allVars[idx] + "\n")
    
    runningModel, labels = discretize (key, allVars[idx], model.copy())
    
    labels = np.around(labels)
        
    print(labels.value_counts())

    # data is split into training/test 
    # split into train and test in a stratified manner
    xtrain, xtest, ytrain, ytest = train_test_split(runningModel, 
                                                    labels, 
                                                    test_size = size)

    
    scatter, highestVal, bestCross = regression_lasso_cross(key, xtrain, xtest, ytrain, ytest, 33)
    
    modelStatus.append([allVars[idx], highestVal, bestCross])
    
    print("Valuable features for " + allVars[idx] + " include: \n")
    regression_lasso(xtrain, xtest, ytrain, ytest, bestCross, 33, True, runningModel.columns )
    
sumFull = 0
sumPart = 0

for i in range(0, len(modelStatus)): 
    if i % 2 == 0: 
        # if even, it is the full thing (less accurate)
        sumFull = sumFull + modelStatus[i][1]
    else: 
        # if odd, it is consolidated version 
        sumPart += modelStatus[i][1]

print("Full model average : " + str(sumFull / 5))
print("Consolidated model average : " + str(sumPart / 5))

modelStatus
# Out:
# Let's work on econInfluence
#
#  4.0    806
#  3.0    776
#  2.0    429
# -1.0    305
#  1.0     84
# Name: econInfluence, dtype: int64
# Valuable features for econInfluence include:
#
# Model coefficients:
# [['urban', 0.15456230651372263], ['cellService', 0.17628427906734234], ['roadblocksCom', 0.1604155485895], ['age', 0.0036375412331899914], ['livingConditionOthers', -0.03419967128882476], ['prevEconConditions', -0.07709458053005282], ['oftenWOWater', 0.029154363726672267], ['oftenWOFuel', 0.026209054953383385], ['remittance', 0.04729436294884446], ['fearedCrime', 0.01673487356631471], ['radioNews', 0.06326847309249557], ['tvNews', 0.09833946708894578], ['newspaperNews', 0.021294233804961114], ['internetNews', 0.023505642686649363], ['socialMediaNews', 0.0394928663326519], ['interestPA', 0.0009733928620541748], ['discussPolitics', 0.02226456141962671], ['freePolitics', 0.015744996035034042], ['freeVote', 0.034736858890806514], ['govBanOrgs', -0.07394405724436307], ['govControlMedia', 0.0032621948242074475], ['freqRaiseIssue', -0.01401266875760225], ['electionFree', 0.052293304051503266], ['contactPPO', 0.00614415468794758], ['contactTLeader', 0.029700051201099135], ['contactRLeader', 0.03983736550476242], ['refusePayDis', -0.0006431130953262975], ['govEffective', 0.045216342433517895], ['presNoLaws', -0.0038929985050531603], ['obeyLaw', 0.06852933644952891], ['payTaxes', 0.04039447831602584], ['payTaxesDevelop', 0.015458036104147047], ['partyConflict', 0.08287513577233287], ['electionRemove', 0.03201811608617515], ['electOppo', -0.028531527934808742], ['electMedia', 0.024796212135338613], ['electChoice', -0.143252847160503], ['electThreat', -0.020708412386234287], ['politicalFear', 0.016169939772640075], ['carefulSay', 0.08181209987351042], ['officialsUnpunished', 0.010257827109700572], ['peopleUnpunished', 0.03127015527606948], ['trustTax', 0.12819532183470525], ['trustPolice', 0.011555789677015064], ['trustRLeaders', -0.015384962510683798], ['corruptPres', 0.0075244450084788785], ['corruptJudges', -0.011096494446925306], ['corruption', 0.057761128172934294], ['difficultyMedical', -0.0006952255754570662], ['difficultyID', -0.06219574122987594], ['bribePolice', -0.02614183456897111], ['povertyProb', -0.10743287557291807], ['unemploymentProb.1', 0.0008691596910496077], ['taxHealthFavor', 0.024523115203203497], ['wrongTaxes', 0.030644355537419406], ['female', -0.0007063940785083196], ['employed', 0.06404788187728123], ['phoneOwn', 0.018232525899061987], ['toleranceReligion', 0.05329630205637841], ['toleranceEthnic', 0.000531203306129065], ['toleranceSex', -0.024372373648345432], ['nearBRIDistance', 0.00039681327848344094]]
#
# Model features removed include:
#  ['electricityGrid', 'pipedWater', 'sewage', 'postOffice', 'schoolAccess', 'policeStation', 'healthClinic', 'market', 'bank', 'transport', 'policeSeen', 'solidiersSeen', 'roadblocksArmy', 'customs', 'pavedRoad', 'roadImpass', 'Hausa', 'Igbo', 'Yoruba', 'rDirection', 'countryEconCondition', 'livingCondition', 'futureEconConditions', 'oftenWOFood', 'oftenWOMed', 'oftenWOCash', 'unsafeNeighborhood', 'beenRobbed', 'beenAttacked', 'freeSpeech', 'govBanOrgsBin', 'govControlMediaBin', 'involveReligous', 'involveCommunityGroup', 'freqCommunityMeetings', 'voted', 'impairedToVote', 'participateRally', 'participateMeeting', 'participatePersuade', 'participateCampaign', 'contactGC', 'contactMP', 'contactGA', 'contactWGroup', 'contactCommunityProblem', 'doVote', 'doNotCritGov', 'doNotComplain', 'doGetHelpLeaders', 'doTaxes', 'doAgree', 'requestActionDis', 'contactMediaDis', 'contactGovDis', 'participateDemoDis', 'govAccountable', 'leaderElect', 'leaderOther', 'politicalPartyValue', 'presOversight', 'opposition', 'mediaReportGov', 'parliMakeLaws', 'presTermLimit', 'extentDemocracy', 'satisfactionDemocracy', 'courtsBinding', 'obeyGov', 'mediaDis', 'presLawless', 'partySilenced', 'presIgnorePA', 'mediaHelps', 'electionRepresent', 'electVotes', 'electBribe', 'leadersServe', 'treatedUnequal', 'trustPres', 'trustParliament', 'trustElectoralC', 'trustLocalGov', 'trustRParty', 'trustOParty', 'trustArmy', 'trustLaw', 'trustLeaders', 'corruptParliament', 'corruptGovOfficials', 'corruptLocalGov', 'corruptPolice', 'corruptTax', 'corruptLeaders', 'corruptRLeaders', 'corruptBusExec', 'difficultySchool', 'bribeSchool', 'bribeMedical', 'bribeID', 'difficultyHousehold', 'bribeHousehold', 'difficultyPolice', 'reportBribe', 'authReactBribe', 'retalBribe', 'corruptionTroubleReport', 'corruptionReported', 'corruptionEgal', 'corruptionThreat', 'agMarketingProb', 'agProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'corruptionProb', 'crimeProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'educationProb', 'electricityProb', 'famineProb', 'genderProb', 'healthProb', 'housingProb', 'landProb', 'loanProb', 'loanProb.1', 'manageEconProb', 'manageEconProb.1', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'povertyProb.1', 'roadProb', 'servicesProb', 'taxProb', 'taxProb.1', 'transportProb', 'unemploymentProb', 'wagesProb', 'wagesProb.1', 'waterProb', 'peopleFightCorrupt', 'wrongService', 'democracyB', 'democracyG', 'democracyPointless', 'partyClose', 'AllProgressCongress', 'PeopleDemocratic', 'radioOwn', 'teleOwn', 'motorOwn', 'toleranceAIDs', 'toleranceImmigrants']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.029830735228806367
#
# Let's work on econInfluence
#
# 1.0    2309
# 0.0      91
# Name: econInfluence, dtype: int64
# Valuable features for econInfluence include:
#
# Model coefficients:
# [['age', 9.931909552339939e-05], ['futureEconConditions', 0.003300562899131636], ['oftenWOCash', -0.0008834953675283061], ['unsafeNeighborhood', -0.002794043475607706], ['fearedCrime', -6.687614186998947e-06], ['freeSpeech', 0.0006049173651553782], ['govControlMedia', 0.0030387719922904226], ['electThreat', 0.005367722387919903], ['treatedUnequal', -0.002712209037832479], ['peopleUnpunished', 0.0013388966430700477], ['bribePolice', -0.003648816785152372], ['toleranceReligion', 0.0038444305380252383], ['toleranceAIDs', 0.0014819117699195342], ['toleranceImmigrants', 0.0014072499624171318], ['nearBRIDistance', -0.00015739454265049788]]
#
# Model features removed include:
#  ['urban', 'electricityGrid', 'pipedWater', 'sewage', 'cellService', 'postOffice', 'schoolAccess', 'policeStation', 'healthClinic', 'market', 'bank', 'transport', 'policeSeen', 'solidiersSeen', 'roadblocksArmy', 'customs', 'roadblocksCom', 'pavedRoad', 'roadImpass', 'Hausa', 'Igbo', 'Yoruba', 'rDirection', 'countryEconCondition', 'livingCondition', 'livingConditionOthers', 'prevEconConditions', 'oftenWOFood', 'oftenWOWater', 'oftenWOMed', 'oftenWOFuel', 'remittance', 'beenRobbed', 'beenAttacked', 'radioNews', 'tvNews', 'newspaperNews', 'internetNews', 'socialMediaNews', 'interestPA', 'discussPolitics', 'freePolitics', 'freeVote', 'govBanOrgs', 'govBanOrgsBin', 'govControlMediaBin', 'involveReligous', 'involveCommunityGroup', 'freqCommunityMeetings', 'freqRaiseIssue', 'voted', 'impairedToVote', 'electionFree', 'participateRally', 'participateMeeting', 'participatePersuade', 'participateCampaign', 'contactGC', 'contactMP', 'contactGA', 'contactPPO', 'contactTLeader', 'contactRLeader', 'contactWGroup', 'contactCommunityProblem', 'doVote', 'doNotCritGov', 'doNotComplain', 'doGetHelpLeaders', 'doTaxes', 'doAgree', 'requestActionDis', 'contactMediaDis', 'contactGovDis', 'refusePayDis', 'participateDemoDis', 'govEffective', 'govAccountable', 'leaderElect', 'leaderOther', 'politicalPartyValue', 'presOversight', 'opposition', 'mediaReportGov', 'parliMakeLaws', 'presNoLaws', 'presTermLimit', 'extentDemocracy', 'satisfactionDemocracy', 'courtsBinding', 'obeyLaw', 'payTaxes', 'obeyGov', 'payTaxesDevelop', 'mediaDis', 'partyConflict', 'presLawless', 'partySilenced', 'presIgnorePA', 'mediaHelps', 'electionRepresent', 'electionRemove', 'electVotes', 'electOppo', 'electMedia', 'electBribe', 'electChoice', 'politicalFear', 'leadersServe', 'carefulSay', 'officialsUnpunished', 'trustPres', 'trustParliament', 'trustElectoralC', 'trustTax', 'trustLocalGov', 'trustRParty', 'trustOParty', 'trustPolice', 'trustArmy', 'trustLaw', 'trustLeaders', 'trustRLeaders', 'corruptPres', 'corruptParliament', 'corruptGovOfficials', 'corruptLocalGov', 'corruptPolice', 'corruptTax', 'corruptJudges', 'corruptLeaders', 'corruptRLeaders', 'corruptBusExec', 'corruption', 'difficultySchool', 'bribeSchool', 'difficultyMedical', 'bribeMedical', 'difficultyID', 'bribeID', 'difficultyHousehold', 'bribeHousehold', 'difficultyPolice', 'reportBribe', 'authReactBribe', 'retalBribe', 'corruptionTroubleReport', 'corruptionReported', 'corruptionEgal', 'corruptionThreat', 'agMarketingProb', 'agProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'corruptionProb', 'crimeProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'educationProb', 'electricityProb', 'famineProb', 'genderProb', 'healthProb', 'housingProb', 'landProb', 'loanProb', 'loanProb.1', 'manageEconProb', 'manageEconProb.1', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'povertyProb', 'povertyProb.1', 'roadProb', 'servicesProb', 'taxProb', 'taxProb.1', 'transportProb', 'unemploymentProb', 'unemploymentProb.1', 'wagesProb', 'wagesProb.1', 'waterProb', 'taxHealthFavor', 'peopleFightCorrupt', 'wrongService', 'wrongTaxes', 'female', 'employed', 'democracyB', 'democracyG', 'democracyPointless', 'partyClose', 'AllProgressCongress', 'PeopleDemocratic', 'radioOwn', 'teleOwn', 'motorOwn', 'phoneOwn', 'toleranceEthnic', 'toleranceSex']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.009763210543336414
#
# Let's work on posnegInfluence
# 4.0    1030
# 3.0     639
# 5.0     567
# 2.0     120
# 1.0      44
# Name: posnegInfluence, dtype: int64
# Valuable features for posnegInfluence include:
#
# Model coefficients:
# [['urban', 0.03204062026288049], ['cellService', 0.15503930782392847], ['policeStation', -0.0025126300030322204], ['healthClinic', 0.052883802615355975], ['bank', -0.06251815559148145], ['roadblocksArmy', 0.018685237668397785], ['pavedRoad', -0.008058938269764471], ['age', -0.0012473079499995383], ['countryEconCondition', -0.01935625273361782], ['livingCondition', 0.005807702283144825], ['livingConditionOthers', -0.046182686238336525], ['prevEconConditions', -0.0213244131395899], ['futureEconConditions', 0.01261671162498895], ['oftenWOFood', 0.007939296754684399], ['oftenWOWater', -0.047446271905114246], ['oftenWOFuel', 0.03289890393378414], ['oftenWOCash', -0.00558714565759665], ['remittance', 0.014984931093481584], ['unsafeNeighborhood', -0.02377503854907279], ['fearedCrime', 0.015962837442874727], ['beenRobbed', 0.013317089277712264], ['radioNews', -0.009798985155638288], ['tvNews', 0.027381122449700767], ['interestPA', 0.004104644403420662], ['freeSpeech', 0.0150681481331923], ['freeVote', 0.018417214663689275], ['govBanOrgs', -0.04076302926184952], ['govBanOrgsBin', 0.014633399139954543], ['govControlMedia', 0.011886369393325304], ['involveReligous', 0.027164322225328476], ['freqCommunityMeetings', -0.02172940119982524], ['voted', 0.12215770502941188], ['electionFree', 0.033801655436398646], ['participatePersuade', 0.0582440241323109], ['contactMP', 0.002271848711548598], ['contactPPO', -0.0016649202283853877], ['contactTLeader', 0.002910209904718287], ['contactRLeader', 0.002545685993836457], ['doNotCritGov', 0.01991796947443395], ['doNotComplain', -0.02512495521915114], ['doTaxes', 0.004420055584755448], ['doAgree', 0.0799502927000238], ['contactMediaDis', 0.004132936238271804], ['refusePayDis', 0.03752390284690364], ['participateDemoDis', -0.027393506611933162], ['govEffective', 0.006253963594611385], ['politicalPartyValue', 0.008525438500294923], ['presOversight', 0.0009061199945074663], ['mediaReportGov', 0.09948318433287492], ['presNoLaws', -0.049572778597857664], ['presTermLimit', 0.013253493841791305], ['extentDemocracy', 0.016521500086947968], ['payTaxesDevelop', 0.04778751753984558], ['mediaDis', -0.03463602765844357], ['partyConflict', 0.005589454899459154], ['partySilenced', 0.02232325775761142], ['mediaHelps', 0.0418616628185867], ['electionRemove', 0.022989451500603105], ['electVotes', 0.05584616426234834], ['electOppo', -0.022749360005343087], ['electMedia', -0.010600402429701748], ['electBribe', 0.005072328121995683], ['electChoice', -0.07227591806945652], ['politicalFear', 0.02910961613146941], ['leadersServe', -0.012655270651426851], ['carefulSay', 0.06309932646638908], ['treatedUnequal', 0.012277405075231989], ['officialsUnpunished', -0.01724652175753152], ['peopleUnpunished', 0.022157219097918884], ['trustElectoralC', -0.04647261430647338], ['trustTax', 0.06355556729201169], ['trustRParty', 0.063914468931662], ['trustOParty', -0.028542236066865748], ['trustPolice', 0.005725949637900644], ['trustLaw', -0.021423245880319308], ['trustRLeaders', 0.013820051622644186], ['corruptPres', 0.028249756695440303], ['corruptParliament', 0.03181697927844846], ['corruptLocalGov', 0.017221617194664467], ['corruptPolice', -0.046056611369642855], ['corruptJudges', -0.0048704039171065605], ['corruptLeaders', -0.011442536176040475], ['corruptBusExec', -0.06012907286122663], ['corruption', 0.08661011884440581], ['difficultySchool', -0.021999444391143794], ['bribeSchool', 0.05064707641681108], ['bribeMedical', -0.02959457812646147], ['difficultyPolice', 0.022207250378044753], ['bribePolice', -0.09847788097516284], ['reportBribe', -0.028274615440190665], ['agProb', -0.13032072549241128], ['corruptionProb', 0.03292959471989744], ['crimeProb', 0.02598533256846575], ['manageEconProb', 0.02098149065238724], ['povertyProb', -0.03366942311474675], ['roadProb', 0.08602611349221947], ['taxProb.1', -0.1042648462824595], ['unemploymentProb', -0.014456697953323308], ['unemploymentProb.1', 0.004214238789161678], ['taxHealthFavor', -0.01 ...
#
# Model features removed include:
#  ['electricityGrid', 'pipedWater', 'sewage', 'postOffice', 'schoolAccess', 'market', 'transport', 'policeSeen', 'solidiersSeen', 'customs', 'roadblocksCom', 'roadImpass', 'Hausa', 'Igbo', 'Yoruba', 'rDirection', 'oftenWOMed', 'beenAttacked', 'newspaperNews', 'internetNews', 'socialMediaNews', 'discussPolitics', 'freePolitics', 'govControlMediaBin', 'involveCommunityGroup', 'freqRaiseIssue', 'impairedToVote', 'participateRally', 'participateMeeting', 'participateCampaign', 'contactGC', 'contactGA', 'contactWGroup', 'contactCommunityProblem', 'doVote', 'doGetHelpLeaders', 'requestActionDis', 'contactGovDis', 'govAccountable', 'leaderElect', 'leaderOther', 'opposition', 'parliMakeLaws', 'satisfactionDemocracy', 'courtsBinding', 'obeyLaw', 'payTaxes', 'obeyGov', 'presLawless', 'presIgnorePA', 'electionRepresent', 'electThreat', 'trustPres', 'trustParliament', 'trustLocalGov', 'trustArmy', 'trustLeaders', 'corruptGovOfficials', 'corruptTax', 'corruptRLeaders', 'difficultyMedical', 'difficultyID', 'bribeID', 'difficultyHousehold', 'bribeHousehold', 'authReactBribe', 'retalBribe', 'corruptionTroubleReport', 'corruptionReported', 'corruptionEgal', 'corruptionThreat', 'agMarketingProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'educationProb', 'electricityProb', 'famineProb', 'genderProb', 'healthProb', 'housingProb', 'landProb', 'loanProb', 'loanProb.1', 'manageEconProb.1', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'povertyProb.1', 'servicesProb', 'taxProb', 'transportProb', 'wagesProb', 'wagesProb.1', 'waterProb', 'peopleFightCorrupt', 'wrongService', 'wrongTaxes', 'female', 'democracyB', 'democracyG', 'partyClose', 'AllProgressCongress', 'PeopleDemocratic', 'radioOwn', 'teleOwn', 'toleranceEthnic', 'toleranceSex']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.008276789630368521
#
# Let's work on posnegInfluence
#
# 3.0    1597
# 2.0     639
# 1.0     164
# Name: posnegInfluence, dtype: int64
# Valuable features for posnegInfluence include:
#
# Model coefficients:
# [['age', -1.7967941446374942e-05], ['countryEconCondition', -0.008988204060603392], ['livingConditionOthers', -0.020614694573574555], ['oftenWOWater', -0.017653496502076666], ['oftenWOFuel', 0.004750156440015408], ['remittance', 0.012616392737616453], ['tvNews', 0.0022165792708306814], ['internetNews', 0.007127584353175176], ['socialMediaNews', 0.003067500355509825], ['freeSpeech', 0.02456803580514675], ['freeVote', 0.0013394056194422036], ['govBanOrgs', -0.01427713372872704], ['govControlMedia', 0.0003902632410340225], ['voted', 0.042648300263998885], ['electionFree', 0.009515594433146028], ['contactRLeader', 0.006676314803679074], ['doNotCritGov', 0.0037528855622797445], ['doAgree', 0.013844801046216276], ['contactGovDis', -0.021646990874515753], ['politicalPartyValue', 0.013625749434231978], ['presNoLaws', -0.038811309438834526], ['extentDemocracy', 0.0009664825066633918], ['courtsBinding', 0.0033771862852458256], ['obeyLaw', 0.005100766621253057], ['partyConflict', 0.007657822172402693], ['mediaHelps', 0.023148424605445268], ['electionRemove', 0.013804564472999862], ['electChoice', -0.004381588945530191], ['politicalFear', 0.00153718279522809], ['carefulSay', 0.03483405454300679], ['peopleUnpunished', 0.01788553003420346], ['trustTax', 0.021356308213872015], ['trustRParty', 0.014610791401016334], ['corruptJudges', -0.016641406621684483], ['corruptBusExec', -0.0035346561803789762], ['corruption', 0.06189225478767798], ['difficultyMedical', -0.009792724001609082], ['bribePolice', -0.0470417381675332], ['taxProb.1', -0.02724857471150797], ['wagesProb.1', 0.0019114644679297892], ['democracyPointless', 0.01641898526376222], ['motorOwn', 0.0019685971774841774], ['toleranceReligion', 0.00746258602211798], ['toleranceEthnic', 0.011117556368437647], ['toleranceSex', -0.005505965789859539], ['nearBRIDistance', 0.0004484542489970571]]
#
# Model features removed include:
#  ['urban', 'electricityGrid', 'pipedWater', 'sewage', 'cellService', 'postOffice', 'schoolAccess', 'policeStation', 'healthClinic', 'market', 'bank', 'transport', 'policeSeen', 'solidiersSeen', 'roadblocksArmy', 'customs', 'roadblocksCom', 'pavedRoad', 'roadImpass', 'Hausa', 'Igbo', 'Yoruba', 'rDirection', 'livingCondition', 'prevEconConditions', 'futureEconConditions', 'oftenWOFood', 'oftenWOMed', 'oftenWOCash', 'unsafeNeighborhood', 'fearedCrime', 'beenRobbed', 'beenAttacked', 'radioNews', 'newspaperNews', 'interestPA', 'discussPolitics', 'freePolitics', 'govBanOrgsBin', 'govControlMediaBin', 'involveReligous', 'involveCommunityGroup', 'freqCommunityMeetings', 'freqRaiseIssue', 'impairedToVote', 'participateRally', 'participateMeeting', 'participatePersuade', 'participateCampaign', 'contactGC', 'contactMP', 'contactGA', 'contactPPO', 'contactTLeader', 'contactWGroup', 'contactCommunityProblem', 'doVote', 'doNotComplain', 'doGetHelpLeaders', 'doTaxes', 'requestActionDis', 'contactMediaDis', 'refusePayDis', 'participateDemoDis', 'govEffective', 'govAccountable', 'leaderElect', 'leaderOther', 'presOversight', 'opposition', 'mediaReportGov', 'parliMakeLaws', 'presTermLimit', 'satisfactionDemocracy', 'payTaxes', 'obeyGov', 'payTaxesDevelop', 'mediaDis', 'presLawless', 'partySilenced', 'presIgnorePA', 'electionRepresent', 'electVotes', 'electOppo', 'electMedia', 'electBribe', 'electThreat', 'leadersServe', 'treatedUnequal', 'officialsUnpunished', 'trustPres', 'trustParliament', 'trustElectoralC', 'trustLocalGov', 'trustOParty', 'trustPolice', 'trustArmy', 'trustLaw', 'trustLeaders', 'trustRLeaders', 'corruptPres', 'corruptParliament', 'corruptGovOfficials', 'corruptLocalGov', 'corruptPolice', 'corruptTax', 'corruptLeaders', 'corruptRLeaders', 'difficultySchool', 'bribeSchool', 'bribeMedical', 'difficultyID', 'bribeID', 'difficultyHousehold', 'bribeHousehold', 'difficultyPolice', 'reportBribe', 'authReactBribe', 'retalBribe', 'corruptionTroubleReport', 'corruptionReported', 'corruptionEgal', 'corruptionThreat', 'agMarketingProb', 'agProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'corruptionProb', 'crimeProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'educationProb', 'electricityProb', 'famineProb', 'genderProb', 'healthProb', 'housingProb', 'landProb', 'loanProb', 'loanProb.1', 'manageEconProb', 'manageEconProb.1', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'povertyProb', 'povertyProb.1', 'roadProb', 'servicesProb', 'taxProb', 'transportProb', 'unemploymentProb', 'unemploymentProb.1', 'wagesProb', 'waterProb', 'taxHealthFavor', 'peopleFightCorrupt', 'wrongService', 'wrongTaxes', 'female', 'employed', 'democracyB', 'democracyG', 'partyClose', 'AllProgressCongress', 'PeopleDemocratic', 'radioOwn', 'teleOwn', 'phoneOwn', 'toleranceAIDs', 'toleranceImmigrants']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.016626066886702255
#
# Let's work on posImageChina
# 4.0    820
# 5.0    571
# 3.0    555
# 1.0    250
# 2.0    170
# 6.0     34
# Name: posImageChina, dtype: int64
# Valuable features for posImageChina include:
#
# Model coefficients:
# [['pipedWater', -0.01132877699469919], ['roadblocksCom', -0.1338867264616438], ['pavedRoad', 0.07886608768481813], ['roadImpass', -0.010688672424430935], ['age', -0.0018215135199870264], ['countryEconCondition', -0.031091607072460177], ['livingConditionOthers', 0.001230146589229459], ['futureEconConditions', 0.021607860022868047], ['oftenWOWater', 0.012756193785133417], ['oftenWOMed', -0.019759290738152465], ['unsafeNeighborhood', -0.02361201234771722], ['fearedCrime', -0.009633376615609429], ['radioNews', 0.00198704822478499], ['newspaperNews', -0.01290031743372659], ['internetNews', -0.0012357282430056557], ['socialMediaNews', -0.011454458865049269], ['interestPA', 0.0009585251572896917], ['freeSpeech', 0.005619295476757012], ['govControlMedia', -0.014742157174412034], ['involveReligous', -0.07544593101723214], ['involveCommunityGroup', -0.03174767189006656], ['electionFree', -0.021778426905531268], ['contactGC', -0.03354696512096828], ['contactGA', -0.10103998835202002], ['doNotComplain', 0.06892487285697384], ['contactMediaDis', -0.042850752049776494], ['contactGovDis', 0.0910259060257769], ['participateDemoDis', -0.01771963265795381], ['politicalPartyValue', 0.042814130616724067], ['opposition', -0.06703353787827873], ['courtsBinding', -0.022728118443635766], ['payTaxes', -0.001265775458360004], ['mediaDis', -0.037001098912258376], ['electionRemove', -0.025499160378741968], ['electOppo', -0.09949283152637903], ['electBribe', -0.028514861687303144], ['electChoice', -0.024496165091472368], ['politicalFear', 0.010782099519110898], ['leadersServe', -0.12251878465995414], ['peopleUnpunished', -0.00506565510589068], ['trustPres', -0.0076960007871300475], ['trustRParty', -0.012147831306959072], ['trustPolice', -0.014898461314636015], ['trustArmy', -0.005714538464572575], ['corruptParliament', -0.05051702835879362], ['corruptTax', -0.041789370712630294], ['corruption', -0.05423172781897771], ['difficultyPolice', 0.004818074031340864], ['peopleFightCorrupt', 0.03890318562056472], ['wrongService', -0.007633061050217114], ['wrongTaxes', -0.011227497519268402], ['toleranceEthnic', 0.012615229015281471], ['toleranceSex', 0.02200234286113881], ['toleranceImmigrants', 0.003913868561672019], ['nearBRIDistance', 0.00013226609302044895]]
#
# Model features removed include:
#  ['urban', 'electricityGrid', 'sewage', 'cellService', 'postOffice', 'schoolAccess', 'policeStation', 'healthClinic', 'market', 'bank', 'transport', 'policeSeen', 'solidiersSeen', 'roadblocksArmy', 'customs', 'Hausa', 'Igbo', 'Yoruba', 'rDirection', 'livingCondition', 'prevEconConditions', 'oftenWOFood', 'oftenWOFuel', 'oftenWOCash', 'remittance', 'beenRobbed', 'beenAttacked', 'tvNews', 'discussPolitics', 'freePolitics', 'freeVote', 'govBanOrgs', 'govBanOrgsBin', 'govControlMediaBin', 'freqCommunityMeetings', 'freqRaiseIssue', 'voted', 'impairedToVote', 'participateRally', 'participateMeeting', 'participatePersuade', 'participateCampaign', 'contactMP', 'contactPPO', 'contactTLeader', 'contactRLeader', 'contactWGroup', 'contactCommunityProblem', 'doVote', 'doNotCritGov', 'doGetHelpLeaders', 'doTaxes', 'doAgree', 'requestActionDis', 'refusePayDis', 'govEffective', 'govAccountable', 'leaderElect', 'leaderOther', 'presOversight', 'mediaReportGov', 'parliMakeLaws', 'presNoLaws', 'presTermLimit', 'extentDemocracy', 'satisfactionDemocracy', 'obeyLaw', 'obeyGov', 'payTaxesDevelop', 'partyConflict', 'presLawless', 'partySilenced', 'presIgnorePA', 'mediaHelps', 'electionRepresent', 'electVotes', 'electMedia', 'electThreat', 'carefulSay', 'treatedUnequal', 'officialsUnpunished', 'trustParliament', 'trustElectoralC', 'trustTax', 'trustLocalGov', 'trustOParty', 'trustLaw', 'trustLeaders', 'trustRLeaders', 'corruptPres', 'corruptGovOfficials', 'corruptLocalGov', 'corruptPolice', 'corruptJudges', 'corruptLeaders', 'corruptRLeaders', 'corruptBusExec', 'difficultySchool', 'bribeSchool', 'difficultyMedical', 'bribeMedical', 'difficultyID', 'bribeID', 'difficultyHousehold', 'bribeHousehold', 'bribePolice', 'reportBribe', 'authReactBribe', 'retalBribe', 'corruptionTroubleReport', 'corruptionReported', 'corruptionEgal', 'corruptionThreat', 'agMarketingProb', 'agProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'corruptionProb', 'crimeProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'educationProb', 'electricityProb', 'famineProb', 'genderProb', 'healthProb', 'housingProb', 'landProb', 'loanProb', 'loanProb.1', 'manageEconProb', 'manageEconProb.1', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'povertyProb', 'povertyProb.1', 'roadProb', 'servicesProb', 'taxProb', 'taxProb.1', 'transportProb', 'unemploymentProb', 'unemploymentProb.1', 'wagesProb', 'wagesProb.1', 'waterProb', 'taxHealthFavor', 'female', 'employed', 'democracyB', 'democracyG', 'democracyPointless', 'partyClose', 'AllProgressCongress', 'PeopleDemocratic', 'radioOwn', 'teleOwn', 'motorOwn', 'phoneOwn', 'toleranceReligion', 'toleranceAIDs']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.025985381484666708
#
# Let's work on posImageChina
#
# 3.0    1329
# 4.0     590
# 1.0     250
# 2.0     197
# 5.0      34
# Name: posImageChina, dtype: int64
# Valuable features for posImageChina include:
#
# Model coefficients:
# [['roadblocksCom', -0.02863587901495851], ['pavedRoad', 0.017407147454106407], ['age', -0.0006225083020492021], ['countryEconCondition', -0.0018003268432456039], ['livingConditionOthers', 0.019223790625527686], ['futureEconConditions', 0.0047102304473608], ['oftenWOMed', -0.004747768334437259], ['remittance', -0.012264223438578317], ['unsafeNeighborhood', -0.02505516574125324], ['fearedCrime', -0.004083504748863955], ['radioNews', 0.004351960067934337], ['tvNews', -0.007045577862505107], ['newspaperNews', -0.001286045428541233], ['internetNews', -0.0027608508971358483], ['freeSpeech', 0.007358988303322657], ['involveReligous', -0.056566464422966874], ['involveCommunityGroup', -0.03065478973474361], ['electionFree', -0.018812438308708497], ['contactGA', -0.07375745756794042], ['contactPPO', -0.015235928052871758], ['doNotComplain', 0.016861169034952925], ['contactGovDis', 0.04091239171574182], ['participateDemoDis', -0.025752212848582003], ['presOversight', -0.001893416762734713], ['courtsBinding', -0.007959477319561354], ['payTaxes', -0.009829834669496877], ['mediaDis', -0.004271022350839571], ['presIgnorePA', 0.0106961130556066], ['electOppo', -0.037436222885322154], ['electBribe', -0.03850958727690789], ['electChoice', -0.004323900046132028], ['politicalFear', 0.008986041797259899], ['leadersServe', -0.08838158124293509], ['peopleUnpunished', -0.02586769494235937], ['trustLocalGov', -0.03327100889220196], ['trustRParty', -0.009261877180705883], ['trustLaw', -0.012481147554095682], ['corruptParliament', -0.06972466365606209], ['corruptTax', -0.001742902318612685], ['corruption', -0.026401803367777765], ['difficultyPolice', 0.010278096131381115], ['peopleFightCorrupt', 0.015988321711664005], ['toleranceSex', 0.012055403390141354], ['toleranceAIDs', -0.00463650025497952], ['toleranceImmigrants', 0.002821043368182385], ['nearBRIDistance', 0.00031989362849895565]]
#
# Model features removed include:
#  ['urban', 'electricityGrid', 'pipedWater', 'sewage', 'cellService', 'postOffice', 'schoolAccess', 'policeStation', 'healthClinic', 'market', 'bank', 'transport', 'policeSeen', 'solidiersSeen', 'roadblocksArmy', 'customs', 'roadImpass', 'Hausa', 'Igbo', 'Yoruba', 'rDirection', 'livingCondition', 'prevEconConditions', 'oftenWOFood', 'oftenWOWater', 'oftenWOFuel', 'oftenWOCash', 'beenRobbed', 'beenAttacked', 'socialMediaNews', 'interestPA', 'discussPolitics', 'freePolitics', 'freeVote', 'govBanOrgs', 'govBanOrgsBin', 'govControlMedia', 'govControlMediaBin', 'freqCommunityMeetings', 'freqRaiseIssue', 'voted', 'impairedToVote', 'participateRally', 'participateMeeting', 'participatePersuade', 'participateCampaign', 'contactGC', 'contactMP', 'contactTLeader', 'contactRLeader', 'contactWGroup', 'contactCommunityProblem', 'doVote', 'doNotCritGov', 'doGetHelpLeaders', 'doTaxes', 'doAgree', 'requestActionDis', 'contactMediaDis', 'refusePayDis', 'govEffective', 'govAccountable', 'leaderElect', 'leaderOther', 'politicalPartyValue', 'opposition', 'mediaReportGov', 'parliMakeLaws', 'presNoLaws', 'presTermLimit', 'extentDemocracy', 'satisfactionDemocracy', 'obeyLaw', 'obeyGov', 'payTaxesDevelop', 'partyConflict', 'presLawless', 'partySilenced', 'mediaHelps', 'electionRepresent', 'electionRemove', 'electVotes', 'electMedia', 'electThreat', 'carefulSay', 'treatedUnequal', 'officialsUnpunished', 'trustPres', 'trustParliament', 'trustElectoralC', 'trustTax', 'trustOParty', 'trustPolice', 'trustArmy', 'trustLeaders', 'trustRLeaders', 'corruptPres', 'corruptGovOfficials', 'corruptLocalGov', 'corruptPolice', 'corruptJudges', 'corruptLeaders', 'corruptRLeaders', 'corruptBusExec', 'difficultySchool', 'bribeSchool', 'difficultyMedical', 'bribeMedical', 'difficultyID', 'bribeID', 'difficultyHousehold', 'bribeHousehold', 'bribePolice', 'reportBribe', 'authReactBribe', 'retalBribe', 'corruptionTroubleReport', 'corruptionReported', 'corruptionEgal', 'corruptionThreat', 'agMarketingProb', 'agProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'corruptionProb', 'crimeProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'educationProb', 'electricityProb', 'famineProb', 'genderProb', 'healthProb', 'housingProb', 'landProb', 'loanProb', 'loanProb.1', 'manageEconProb', 'manageEconProb.1', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'povertyProb', 'povertyProb.1', 'roadProb', 'servicesProb', 'taxProb', 'taxProb.1', 'transportProb', 'unemploymentProb', 'unemploymentProb.1', 'wagesProb', 'wagesProb.1', 'waterProb', 'taxHealthFavor', 'wrongService', 'wrongTaxes', 'female', 'employed', 'democracyB', 'democracyG', 'democracyPointless', 'partyClose', 'AllProgressCongress', 'PeopleDemocratic', 'radioOwn', 'teleOwn', 'motorOwn', 'phoneOwn', 'toleranceReligion', 'toleranceEthnic']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.024880434887785633
#
# Let's work on negImageChina
# 5.0    1158
# 4.0     478
# 3.0     267
# 1.0     239
# 2.0     136
# 6.0     122
# Name: negImageChina, dtype: int64
# Valuable features for negImageChina include:
#
# Model coefficients:
# [['urban', 0.03147608245869668], ['solidiersSeen', 0.16444265444906264], ['roadblocksCom', -0.19377924286754986], ['roadImpass', -0.06575092908351186], ['age', 0.004579523954035672], ['rDirection', 0.025410907212867765], ['livingCondition', -0.066989543608724], ['futureEconConditions', 0.0441229277902404], ['oftenWOWater', -0.01409131077136711], ['oftenWOMed', -0.016292966621180564], ['oftenWOFuel', 0.0423601731657848], ['oftenWOCash', 0.038643288474824934], ['remittance', -0.05690092112031845], ['unsafeNeighborhood', 0.00493644563645455], ['tvNews', 0.004942718654225469], ['newspaperNews', -0.0442910409930033], ['socialMediaNews', -0.00507525171515394], ['discussPolitics', -0.037605684743030526], ['freeSpeech', 0.07924855905611132], ['freePolitics', 0.07186885622050536], ['freeVote', -0.0607724557583645], ['govBanOrgs', 0.018946367612579004], ['involveReligous', -0.058129568989735876], ['involveCommunityGroup', -0.000391294295794652], ['freqCommunityMeetings', 0.006480195361260288], ['freqRaiseIssue', 0.023885356707913228], ['voted', 0.12320740919268987], ['electionFree', 0.04839038757925475], ['contactGC', -0.0028350524279515204], ['contactPPO', -0.09781750641567462], ['contactRLeader', -0.01131521664429237], ['contactCommunityProblem', -0.17220250229909123], ['doVote', -0.14955921218451554], ['doNotComplain', 0.0863271853301859], ['requestActionDis', -0.08056202588109079], ['contactMediaDis', -0.0033380415291506824], ['contactGovDis', 0.04578838386410406], ['refusePayDis', -0.029285524889317207], ['govEffective', -0.031909489303546666], ['politicalPartyValue', -0.01995885746814499], ['presOversight', 0.00396025025533749], ['mediaReportGov', -0.01982748759785392], ['parliMakeLaws', 0.008229966175447344], ['extentDemocracy', 0.009583792578788533], ['satisfactionDemocracy', -0.05740303904538026], ['courtsBinding', 0.008039703593603105], ['obeyLaw', -0.03692577178929701], ['payTaxes', 0.07074135745482653], ['partyConflict', 0.007985547949414834], ['presLawless', 0.011995289963916335], ['partySilenced', -0.038228109364404655], ['mediaHelps', 0.02565417541627983], ['electionRepresent', 0.014144401137484516], ['electionRemove', -0.04603288938573283], ['electOppo', -0.03207335845679701], ['electBribe', -0.04229997396470052], ['electChoice', -0.04244741183804291], ['electThreat', -0.042436999068133814], ['politicalFear', 0.04580052930134894], ['leadersServe', -0.07503920433218572], ['carefulSay', -0.02783585372392844], ['treatedUnequal', -0.012006409023798244], ['peopleUnpunished', -0.07954719364510349], ['trustElectoralC', 0.04913621998037883], ['trustLocalGov', -0.07191749480379064], ['trustRLeaders', -0.010157712713952669], ['corruptPres', -0.015175622289357484], ['corruptLocalGov', 0.03839304569895196], ['corruptPolice', 0.003022926495916427], ['corruptTax', -0.04468270502202741], ['corruption', -0.09330054170439626], ['difficultySchool', 0.09411900582188217], ['bribeSchool', -0.05035791767473215], ['bribeMedical', 0.04142683205946707], ['difficultyID', 0.06295208679377459], ['bribeID', 0.006076311968680833], ['difficultyHousehold', -0.03363411209083319], ['bribeHousehold', -0.014933941015036874], ['bribePolice', 0.05481828709530021], ['corruptionTroubleReport', 0.08003549116159721], ['corruptionThreat', -0.017486512873529078], ['corruptionProb', 0.010583854123905698], ['educationProb', -0.03672217465392758], ['healthProb', -0.10901611122684125], ['manageEconProb.1', -0.03260983852564213], ['povertyProb.1', -0.13555410444470106], ['unemploymentProb', 0.07193107431313212], ['unemploymentProb.1', 0.009232112934102364], ['wagesProb', 0.057403218880157904], ['taxHealthFavor', -0.09777682299091009], ['peopleFightCorrupt', 0.007185544056410848], ['wrongService', 0.08641682850645341], ['wrongTaxes', 0.03608768221031766], ['democracyB', -0.044345706202301834], ['partyClose', -0.071538092187427], ['AllProgressCongress', -0.22612870031724944], ['motorOwn', -0.01533165604667092], ['toleranceReligion', 0.005473242242907447], ['toleranceSex' ...
#
# Model features removed include:
#  ['electricityGrid', 'pipedWater', 'sewage', 'cellService', 'postOffice', 'schoolAccess', 'policeStation', 'healthClinic', 'market', 'bank', 'transport', 'policeSeen', 'roadblocksArmy', 'customs', 'pavedRoad', 'Hausa', 'Igbo', 'Yoruba', 'countryEconCondition', 'livingConditionOthers', 'prevEconConditions', 'oftenWOFood', 'fearedCrime', 'beenRobbed', 'beenAttacked', 'radioNews', 'internetNews', 'interestPA', 'govBanOrgsBin', 'govControlMedia', 'govControlMediaBin', 'impairedToVote', 'participateRally', 'participateMeeting', 'participatePersuade', 'participateCampaign', 'contactMP', 'contactGA', 'contactTLeader', 'contactWGroup', 'doNotCritGov', 'doGetHelpLeaders', 'doTaxes', 'doAgree', 'participateDemoDis', 'govAccountable', 'leaderElect', 'leaderOther', 'opposition', 'presNoLaws', 'presTermLimit', 'obeyGov', 'payTaxesDevelop', 'mediaDis', 'presIgnorePA', 'electVotes', 'electMedia', 'officialsUnpunished', 'trustPres', 'trustParliament', 'trustTax', 'trustRParty', 'trustOParty', 'trustPolice', 'trustArmy', 'trustLaw', 'trustLeaders', 'corruptParliament', 'corruptGovOfficials', 'corruptJudges', 'corruptLeaders', 'corruptRLeaders', 'corruptBusExec', 'difficultyMedical', 'difficultyPolice', 'reportBribe', 'authReactBribe', 'retalBribe', 'corruptionReported', 'corruptionEgal', 'agMarketingProb', 'agProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'crimeProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'electricityProb', 'famineProb', 'genderProb', 'housingProb', 'landProb', 'loanProb', 'loanProb.1', 'manageEconProb', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'povertyProb', 'roadProb', 'servicesProb', 'taxProb', 'taxProb.1', 'transportProb', 'wagesProb.1', 'waterProb', 'female', 'employed', 'democracyG', 'democracyPointless', 'PeopleDemocratic', 'radioOwn', 'teleOwn', 'phoneOwn', 'toleranceEthnic']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.014614605333830945
#
# Let's work on negImageChina
#
# 3.0    1552
# 2.0     371
# 1.0     352
# 4.0     125
# Name: negImageChina, dtype: int64
# Valuable features for negImageChina include:
#
# Model coefficients:
# [['pipedWater', -0.005016919400437718], ['market', 0.0017087647081288934], ['solidiersSeen', 0.074896203234368], ['roadblocksCom', -0.04854551206851387], ['roadImpass', -0.014723877302457456], ['age', 0.002188698313331741], ['livingCondition', -0.0367784012268271], ['prevEconConditions', -0.003661687229108561], ['futureEconConditions', 0.01876444725421485], ['oftenWOFood', 0.008470094541452334], ['oftenWOCash', 0.012958608912281382], ['remittance', -0.001388736625960814], ['beenRobbed', -0.00892958799173394], ['beenAttacked', -0.010165953392508203], ['radioNews', 0.0017832670089757648], ['tvNews', 0.006482822284120339], ['newspaperNews', 0.0007301482104187134], ['socialMediaNews', -0.01995731261846126], ['freeSpeech', 0.028918149226695285], ['freePolitics', 0.02894349986679001], ['freeVote', -0.016149210997325313], ['govBanOrgs', 0.0028028857912728708], ['govControlMedia', 0.015283870799808575], ['involveReligous', -0.0283946122420622], ['involveCommunityGroup', -0.004051735350825292], ['freqCommunityMeetings', 0.022982605809572267], ['freqRaiseIssue', -0.017334146543939076], ['voted', 0.03177445462984063], ['electionFree', 0.030599839932613202], ['contactGA', -0.005049361163635599], ['contactPPO', -0.08851463642013783], ['contactCommunityProblem', -0.05320872681664985], ['doVote', -0.09635556818769521], ['doNotCritGov', -0.0019050096770655538], ['doNotComplain', 0.023777157852582668], ['doAgree', -0.0018679002488499288], ['requestActionDis', -0.02466030291184732], ['contactGovDis', 0.027881968193077457], ['refusePayDis', -0.0022284670080489235], ['participateDemoDis', -0.005409281232941999], ['govEffective', -0.06088579290369594], ['presOversight', 0.004612500258209567], ['mediaReportGov', -0.04649049135924595], ['presTermLimit', -0.015490465657730837], ['extentDemocracy', 0.02487185068079193], ['satisfactionDemocracy', -0.014774819183582963], ['courtsBinding', 0.005905869441829004], ['obeyLaw', -0.030883113379129776], ['payTaxes', 0.03480959082350926], ['mediaDis', -0.006958871479740422], ['presLawless', 0.038948447394528976], ['partySilenced', -0.028550364989631916], ['electionRemove', -0.0308886463760332], ['electOppo', -0.028199885080853], ['electMedia', 0.015801931313791484], ['electBribe', -0.033855503647057326], ['electChoice', -0.02292897510596194], ['electThreat', -0.03735857304336886], ['politicalFear', 0.033189155286879365], ['leadersServe', -0.025656295134153923], ['treatedUnequal', -0.01656974297208267], ['peopleUnpunished', -0.04969603895473617], ['trustParliament', -0.012328447387092422], ['trustElectoralC', 0.03857915720984024], ['trustTax', -0.004496339105381996], ['trustLocalGov', -0.019700118280323857], ['trustRParty', -0.025167247339157126], ['trustLaw', -0.004340492696305718], ['trustLeaders', -0.004748248411092035], ['trustRLeaders', -0.0005263205268351837], ['corruptPres', -0.002974592104272598], ['corruptLocalGov', 0.020002094597750077], ['corruptJudges', 0.0007109827928038033], ['corruptRLeaders', 0.010270390174091096], ['corruption', -0.06416813463749385], ['difficultySchool', 0.014650334126191232], ['bribeSchool', -0.017246177480369697], ['difficultyMedical', 0.017087584657028018], ['difficultyID', 0.028591733614082265], ['bribeID', 0.02611927999014495], ['difficultyHousehold', 0.012309765200087107], ['difficultyPolice', 0.00027918425917893144], ['corruptionTroubleReport', 0.10011488290772583], ['corruptionProb', 0.008137861066325674], ['electricityProb', 0.027292019484356736], ['healthProb', -0.032767325432844635], ['manageEconProb.1', -0.029021163920376444], ['povertyProb.1', -0.11835056231890716], ['unemploymentProb', 0.038343497352397546], ['wagesProb.1', 0.037385740231518506], ['taxHealthFavor', -0.030346748471735505], ['peopleFightCorrupt', 0.005057440299224164], ['wrongService', 0.11238115370548428], ['wrongTaxes', 0.004276164444254599], ['partyClose', -0.02981609410386987], ['AllProgressCongress', -0.13815353978316386], ['toleranceEthnic', 0.004159838973984687], ['toleranceSex', -0.002227507 ...
#
# Model features removed include:
#  ['urban', 'electricityGrid', 'sewage', 'cellService', 'postOffice', 'schoolAccess', 'policeStation', 'healthClinic', 'bank', 'transport', 'policeSeen', 'roadblocksArmy', 'customs', 'pavedRoad', 'Hausa', 'Igbo', 'Yoruba', 'rDirection', 'countryEconCondition', 'livingConditionOthers', 'oftenWOWater', 'oftenWOMed', 'oftenWOFuel', 'unsafeNeighborhood', 'fearedCrime', 'internetNews', 'interestPA', 'discussPolitics', 'govBanOrgsBin', 'govControlMediaBin', 'impairedToVote', 'participateRally', 'participateMeeting', 'participatePersuade', 'participateCampaign', 'contactGC', 'contactMP', 'contactTLeader', 'contactRLeader', 'contactWGroup', 'doGetHelpLeaders', 'doTaxes', 'contactMediaDis', 'govAccountable', 'leaderElect', 'leaderOther', 'politicalPartyValue', 'opposition', 'parliMakeLaws', 'presNoLaws', 'obeyGov', 'payTaxesDevelop', 'partyConflict', 'presIgnorePA', 'mediaHelps', 'electionRepresent', 'electVotes', 'carefulSay', 'officialsUnpunished', 'trustPres', 'trustOParty', 'trustPolice', 'trustArmy', 'corruptParliament', 'corruptGovOfficials', 'corruptPolice', 'corruptTax', 'corruptLeaders', 'corruptBusExec', 'bribeMedical', 'bribeHousehold', 'bribePolice', 'reportBribe', 'authReactBribe', 'retalBribe', 'corruptionReported', 'corruptionEgal', 'corruptionThreat', 'agMarketingProb', 'agProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'crimeProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'educationProb', 'famineProb', 'genderProb', 'housingProb', 'landProb', 'loanProb', 'loanProb.1', 'manageEconProb', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'povertyProb', 'roadProb', 'servicesProb', 'taxProb', 'taxProb.1', 'transportProb', 'unemploymentProb.1', 'wagesProb', 'waterProb', 'female', 'employed', 'democracyB', 'democracyG', 'democracyPointless', 'PeopleDemocratic', 'radioOwn', 'teleOwn', 'motorOwn', 'phoneOwn', 'toleranceReligion', 'toleranceImmigrants']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.009440178452233
#
# Let's work on econAssistance
# 4.0    859
# 3.0    683
# 5.0    528
# 2.0    253
# 1.0     77
# Name: econAssistance, dtype: int64
# Valuable features for econAssistance include:
#
# Model coefficients:
# [['urban', 0.04927690652576329], ['policeStation', -0.055186761521790896], ['roadblocksArmy', 0.02601672047269318], ['age', -0.0005361763079712855], ['rDirection', -0.04748184200868559], ['livingCondition', -0.02055378409422732], ['livingConditionOthers', -0.021027605392430933], ['prevEconConditions', -0.05432853884965245], ['futureEconConditions', 0.01640385243126755], ['oftenWOMed', -0.023112080518031465], ['oftenWOCash', -0.018037500995974547], ['remittance', 0.028169672478951083], ['fearedCrime', -0.008645396688365371], ['newspaperNews', 0.03813151874917287], ['internetNews', 0.0038523651670651295], ['freeVote', 0.012662291393491672], ['govBanOrgs', -0.03564623619587587], ['involveCommunityGroup', -0.00046097634047427197], ['freqCommunityMeetings', -0.04751253092378118], ['freqRaiseIssue', 0.02596429781801621], ['voted', 0.08231709289970968], ['electionFree', 0.020443714743063664], ['participatePersuade', 0.04446504916073396], ['contactGC', -0.00046907462345296004], ['contactGA', -0.060977843738316884], ['contactPPO', -0.058034203122844706], ['contactRLeader', 0.044628669289673115], ['contactCommunityProblem', 0.1177405525362736], ['doVote', 0.1580238400118722], ['doGetHelpLeaders', 0.024171244221023666], ['doTaxes', 0.01265076477435385], ['requestActionDis', -0.01991782225707656], ['contactGovDis', -0.01164898116609167], ['participateDemoDis', -0.04650751131188977], ['govEffective', 0.013176789423268193], ['leaderElect', 0.07395356772403451], ['politicalPartyValue', 0.0022281804413846603], ['presOversight', -0.008415802898452528], ['opposition', -0.018135586170628312], ['mediaReportGov', 0.09453096071079742], ['presNoLaws', -0.007282649905268823], ['extentDemocracy', -0.0061981093818234525], ['obeyLaw', 0.10125270093668645], ['payTaxes', -0.010453626983836685], ['obeyGov', 0.08246358482156524], ['mediaDis', -0.0752438593979087], ['presIgnorePA', -0.050478926030642184], ['mediaHelps', 0.0065344256944421825], ['electionRepresent', 0.0033703558237519254], ['electionRemove', -0.009393057620257148], ['electVotes', 0.0877762684365015], ['electOppo', -0.001742193207225617], ['electChoice', -0.023816806508617307], ['electThreat', -0.007881670155718324], ['trustParliament', 0.01135199136861723], ['trustPolice', -0.004631930466823013], ['trustLaw', -0.007531419633412382], ['trustLeaders', -0.0006508584941059967], ['corruptPres', 0.06102104399903856], ['corruptLocalGov', -0.008756494385386417], ['corruptPolice', 0.013147783772375916], ['corruptJudges', -0.03770595109160827], ['corruptBusExec', -0.0029767796906684345], ['corruption', 0.028014432926238748], ['difficultyMedical', 0.029740010384768086], ['bribeID', -0.09167100602395394], ['reportBribe', -0.025760892211226124], ['unemploymentProb', -0.012611039285005768], ['peopleFightCorrupt', 0.010148100637565435], ['female', -0.03548076991282671], ['employed', 0.018459054892812576], ['democracyPointless', 0.013441796455788548], ['teleOwn', 0.0037386017046773423], ['toleranceReligion', 0.004859235016578328], ['toleranceAIDs', -0.009444931711823947], ['toleranceImmigrants', 0.05401357926287402], ['nearBRIDistance', -5.375875577576288e-05]]
#
# Model features removed include:
#  ['electricityGrid', 'pipedWater', 'sewage', 'cellService', 'postOffice', 'schoolAccess', 'healthClinic', 'market', 'bank', 'transport', 'policeSeen', 'solidiersSeen', 'customs', 'roadblocksCom', 'pavedRoad', 'roadImpass', 'Hausa', 'Igbo', 'Yoruba', 'countryEconCondition', 'oftenWOFood', 'oftenWOWater', 'oftenWOFuel', 'unsafeNeighborhood', 'beenRobbed', 'beenAttacked', 'radioNews', 'tvNews', 'socialMediaNews', 'interestPA', 'discussPolitics', 'freeSpeech', 'freePolitics', 'govBanOrgsBin', 'govControlMedia', 'govControlMediaBin', 'involveReligous', 'impairedToVote', 'participateRally', 'participateMeeting', 'participateCampaign', 'contactMP', 'contactTLeader', 'contactWGroup', 'doNotCritGov', 'doNotComplain', 'doAgree', 'contactMediaDis', 'refusePayDis', 'govAccountable', 'leaderOther', 'parliMakeLaws', 'presTermLimit', 'satisfactionDemocracy', 'courtsBinding', 'payTaxesDevelop', 'partyConflict', 'presLawless', 'partySilenced', 'electMedia', 'electBribe', 'politicalFear', 'leadersServe', 'carefulSay', 'treatedUnequal', 'officialsUnpunished', 'peopleUnpunished', 'trustPres', 'trustElectoralC', 'trustTax', 'trustLocalGov', 'trustRParty', 'trustOParty', 'trustArmy', 'trustRLeaders', 'corruptParliament', 'corruptGovOfficials', 'corruptTax', 'corruptLeaders', 'corruptRLeaders', 'difficultySchool', 'bribeSchool', 'bribeMedical', 'difficultyID', 'difficultyHousehold', 'bribeHousehold', 'difficultyPolice', 'bribePolice', 'authReactBribe', 'retalBribe', 'corruptionTroubleReport', 'corruptionReported', 'corruptionEgal', 'corruptionThreat', 'agMarketingProb', 'agProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'corruptionProb', 'crimeProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'educationProb', 'electricityProb', 'famineProb', 'genderProb', 'healthProb', 'housingProb', 'landProb', 'loanProb', 'loanProb.1', 'manageEconProb', 'manageEconProb.1', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'povertyProb', 'povertyProb.1', 'roadProb', 'servicesProb', 'taxProb', 'taxProb.1', 'transportProb', 'unemploymentProb.1', 'wagesProb', 'wagesProb.1', 'waterProb', 'taxHealthFavor', 'wrongService', 'wrongTaxes', 'democracyB', 'democracyG', 'partyClose', 'AllProgressCongress', 'PeopleDemocratic', 'radioOwn', 'motorOwn', 'phoneOwn', 'toleranceEthnic', 'toleranceSex']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.014261926356391046
#
# Let's work on econAssistance
#
# 3.0    1376
# 2.0     694
# 1.0     330
# Name: econAssistance, dtype: int64
# Valuable features for econAssistance include:
#
# Model coefficients:
# [['urban', 0.032747258356051204], ['postOffice', 0.0023087456267829984], ['policeStation', -0.010952782968150734], ['bank', 0.023780919808003922], ['pavedRoad', -0.04226429657950207], ['age', -0.00282384582162938], ['rDirection', -0.008370954334999813], ['countryEconCondition', -0.005879139220297705], ['livingCondition', -0.007414896519905221], ['livingConditionOthers', -0.0201875721818136], ['prevEconConditions', -0.02738671649859028], ['futureEconConditions', -0.0025389328587232117], ['oftenWOFuel', 0.0172386283477993], ['oftenWOCash', -0.030650675717121018], ['remittance', 0.004952908431629025], ['unsafeNeighborhood', -0.0011202448430817293], ['fearedCrime', -0.018011559512834216], ['beenAttacked', 0.026987281739307343], ['radioNews', 0.004701635229334892], ['tvNews', -0.0033473691864223543], ['newspaperNews', 0.008366515446510226], ['interestPA', 0.003478182590595717], ['discussPolitics', 0.0011910597846024936], ['freeVote', -0.0019022399055015724], ['govBanOrgs', -0.006221557206379975], ['govControlMedia', -0.004172544763586314], ['freqCommunityMeetings', -0.011575325811365106], ['freqRaiseIssue', 0.022680401787656474], ['voted', 0.04503187192148757], ['electionFree', 0.0033318021542465917], ['participateRally', 0.007948028168546018], ['participatePersuade', 0.015229365285335191], ['contactGA', -0.012953759920033446], ['contactPPO', -0.05127451070531747], ['contactRLeader', 0.024403213731668094], ['contactCommunityProblem', 0.005891591286640376], ['doVote', 0.0536031104017841], ['doNotComplain', 0.015076816108902191], ['doGetHelpLeaders', 0.011512212444599766], ['doTaxes', 0.010049830961710167], ['requestActionDis', -0.011233949093589103], ['contactGovDis', -0.048314345245056414], ['refusePayDis', 0.021511371246584185], ['participateDemoDis', -0.04314944522359493], ['govEffective', 0.009508636830505068], ['leaderElect', 0.030849613577230962], ['politicalPartyValue', 0.0012023344120760256], ['presOversight', -0.015274004799831728], ['opposition', -0.06678703390902249], ['mediaReportGov', 0.05310049962327007], ['parliMakeLaws', 0.05889411691172435], ['presTermLimit', 0.0005140267867750447], ['extentDemocracy', -0.036866817786713364], ['satisfactionDemocracy', -0.0008013563304017428], ['courtsBinding', 0.0007169287311281333], ['obeyLaw', 0.07273975717388195], ['obeyGov', 0.07934464802925276], ['payTaxesDevelop', 0.0017427449798973107], ['mediaDis', -0.026469781934725], ['presLawless', -0.011675329781868393], ['presIgnorePA', -0.042918990929384775], ['electionRemove', -0.0005080777886056702], ['electVotes', 0.052285924135815065], ['electOppo', -0.042969995601313545], ['electChoice', -0.03540953227022708], ['electThreat', -0.01591769627027759], ['politicalFear', -0.004477697746548193], ['leadersServe', -0.014716712193420654], ['carefulSay', 0.009204763230168778], ['treatedUnequal', -0.0025815465314305112], ['peopleUnpunished', -0.004998373199628824], ['trustElectoralC', -0.02690885844051761], ['trustTax', 0.01321204912771515], ['trustLocalGov', -0.008553632954155375], ['trustRParty', -0.008850287025100899], ['trustLeaders', 0.0052422214134004415], ['corruptPres', 0.012495713590804045], ['corruptGovOfficials', 0.006589403935325641], ['corruptJudges', -0.0017645183035565745], ['corruption', 0.033535910668397687], ['difficultySchool', -0.03911873334013898], ['bribeSchool', 0.015358928620822252], ['bribeMedical', -0.010885446014374437], ['difficultyID', -0.0010955857916959712], ['bribeID', -0.042944460912713506], ['difficultyHousehold', 0.004455184065060938], ['bribePolice', 0.0035496488175382084], ['reportBribe', -0.017213380164292986], ['loanProb.1', -0.029904071380536665], ['manageEconProb', -0.09156664261566709], ['povertyProb', -0.02571265425188766], ['povertyProb.1', 0.0033861026652150577], ['wagesProb.1', 0.04365067012075296], ['peopleFightCorrupt', 0.0031071101666129215], ['wrongService', 0.012771648936237867], ['radioOwn', 0.06046893302480205], ['teleOwn', 0.003941155211273905], ['motorOwn', 0.04607916873491987], ['tolera ...
#
# Model features removed include:
#  ['electricityGrid', 'pipedWater', 'sewage', 'cellService', 'schoolAccess', 'healthClinic', 'market', 'transport', 'policeSeen', 'solidiersSeen', 'roadblocksArmy', 'customs', 'roadblocksCom', 'roadImpass', 'Hausa', 'Igbo', 'Yoruba', 'oftenWOFood', 'oftenWOWater', 'oftenWOMed', 'beenRobbed', 'internetNews', 'socialMediaNews', 'freeSpeech', 'freePolitics', 'govBanOrgsBin', 'govControlMediaBin', 'involveReligous', 'involveCommunityGroup', 'impairedToVote', 'participateMeeting', 'participateCampaign', 'contactGC', 'contactMP', 'contactTLeader', 'contactWGroup', 'doNotCritGov', 'doAgree', 'contactMediaDis', 'govAccountable', 'leaderOther', 'presNoLaws', 'payTaxes', 'partyConflict', 'partySilenced', 'mediaHelps', 'electionRepresent', 'electMedia', 'electBribe', 'officialsUnpunished', 'trustPres', 'trustParliament', 'trustOParty', 'trustPolice', 'trustArmy', 'trustLaw', 'trustRLeaders', 'corruptParliament', 'corruptLocalGov', 'corruptPolice', 'corruptTax', 'corruptLeaders', 'corruptRLeaders', 'corruptBusExec', 'difficultyMedical', 'bribeHousehold', 'difficultyPolice', 'authReactBribe', 'retalBribe', 'corruptionTroubleReport', 'corruptionReported', 'corruptionEgal', 'corruptionThreat', 'agMarketingProb', 'agProb', 'aidsProb', 'bokoProb', 'civilWarProb', 'communicationsProb', 'corruptionProb', 'crimeProb', 'discrimProb', 'diseaseProb', 'droughtProb', 'droughtProb.1', 'educationProb', 'electricityProb', 'famineProb', 'genderProb', 'healthProb', 'housingProb', 'landProb', 'loanProb', 'manageEconProb.1', 'orphansProb', 'politInstableProb', 'politRightsProb', 'politViolenceProb', 'roadProb', 'servicesProb', 'taxProb', 'taxProb.1', 'transportProb', 'unemploymentProb', 'unemploymentProb.1', 'wagesProb', 'waterProb', 'taxHealthFavor', 'wrongTaxes', 'female', 'employed', 'democracyB', 'democracyG', 'democracyPointless', 'partyClose', 'AllProgressCongress', 'PeopleDemocratic', 'phoneOwn', 'toleranceSex']
#
# The shinkage coefficient hyperparameter chosen by CV: 0.007845188565259882
# Full model average : 0.355
# Consolidated model average : 0.64
# [['econInfluence', 0.28833333333333333, 2],
#  ['econInfluence', 0.96, 2],
#  ['posnegInfluence', 0.46, 15],
#  ['posnegInfluence', 0.6316666666666667, 2],
#  ['posImageChina', 0.3466666666666667, 4],
#  ['posImageChina', 0.59, 2],
#  ['negImageChina', 0.30666666666666664, 9],
#  ['negImageChina', 0.53, 4],
#  ['econAssistance', 0.37333333333333335, 7],
#  ['econAssistance', 0.48833333333333334, 8]]
